# %%
import pandas as pd
import re
import numpy as np

# %%
times_data=pd.read_csv("Downloads/2020/timesData.csv")
mr_data=times_data.iloc[times_data.groupby('university_name')['year'].idxmax()]
mr_data.head()
lr_data=times_data.iloc[times_data.groupby('university_name')['year'].idxmin()]
lr_data.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 501     301-350                        Aalborg University         Denmark
# 502     301-350                          Aalto University         Finland
# 166         167                         Aarhus University         Denmark
# 476     276-300                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations income total_score  \
# 2405      14.2          17.9       3.7       35.7      -           -
# 501       19.0          75.3      20.0       27.1   36.4           -
# 502       26.2          49.0      22.2       37.5   61.9           -
# 166       38.1          33.4      55.6       57.3   61.5        49.9
# 476       19.8          63.8      15.5       56.6   35.5           -
#
#      num_students  student_staff_ratio international_students  \
# ...

# %%
A=times_data.groupby(['university_name','year'],as_index=False).size()
A[A['size']>1]
cwurData=pd.read_csv("Downloads/2020/cwurData.csv")
B=cwurData.groupby(['institution','year'],as_index=False).size()
B[B['size']>1]
shanghaiData=pd.read_csv('Downloads/2020/shanghaiData.csv')
C=shanghaiData.groupby(['university_name','year'],as_index=False).size()
C[C['size']>1]
# Out:
#                         university_name  year  size
# 1640                 Queen's University  2007     2
# 1641                 Queen's University  2008     2
# 1643                 Queen's University  2010     2
# 3643  University of Maryland, Baltimore  2007     2
# 3644  University of Maryland, Baltimore  2008     2
# 3731                University of Milan  2010     2

# %%
shanghaiData[shanghaiData['university_name']=="Queen's University"]
# Out:
#      world_rank     university_name national_rank  total_score  alumni  award  \
# 164     153-202  Queen's University           6-8          NaN     0.0    0.0
# 660     151-200  Queen's University           6-8          NaN     0.0    0.0
# 1233    203-304  Queen's University          8-17          NaN     0.0    0.0
# 1234    203-304  Queen's University         24-33          NaN    22.0    0.0
# 1739    201-302  Queen's University          7-18          NaN     0.0    0.0
# 1740    201-302  Queen's University         23-33          NaN    20.9    0.0
# 2240    201-302  Queen's University          7-18          NaN     0.0    0.0
# 2741    201-300  Queen's University          9-18          NaN     0.0    0.0
# 2742    201-300  Queen's University         20-30          NaN    19.9    0.0
# 3240    201-300  Queen's University          9-18          NaN     0.0    0.0
# 3742    201-300  Queen's University          8-17          NaN     0.0    0.0
# ...

# %%
shanghaiData[shanghaiData['university_name']=="University of Maryland, Baltimore"]
# Out:
#      world_rank                    university_name national_rank  total_score  \
# 187     153-202  University of Maryland, Baltimore         72-90          NaN
# 684     151-200  University of Maryland, Baltimore         70-87          NaN
# 1185    151-202  University of Maryland, Baltimore         71-88          NaN
# 1484    403-510  University of Maryland, Baltimore       141-166          NaN
# 1693    152-200  University of Maryland, Baltimore         71-90          NaN
# 1992    402-503  University of Maryland, Baltimore       140-159          NaN
# 2199    152-200  University of Maryland, Baltimore         71-90          NaN
# 2701    151-200  University of Maryland, Baltimore         70-89          NaN
# 3198    151-200  University of Maryland, Baltimore         69-89          NaN
# 3697    151-200  University of Maryland, Baltimore         68-85          NaN
# 4172    201-300  University of Maryland, Baltimore        78-104          NaN
# ...

# %%
shanghaiData[shanghaiData['university_name']=="University of Milan"]
# Out:
#      world_rank      university_name national_rank  total_score  alumni  \
# 141     101-152  University of Milan           2-3          NaN    22.6
# 638     102-150  University of Milan           2-3          NaN    21.8
# 1137    102-150  University of Milan             1          NaN    21.2
# 1649    101-151  University of Milan           1-3          NaN    20.2
# 2151    101-151  University of Milan           1-3          NaN    19.7
# 2650    101-150  University of Milan           1-3          NaN    19.2
# 2988    401-500  University of Milan         14-22          NaN     0.0
# 3200    151-200  University of Milan           3-4          NaN    19.5
# 3699    151-200  University of Milan           3-4          NaN    18.0
# 4082    151-200  University of Milan           1-6          NaN    17.5
# 4585    151-200  University of Milan           1-5          NaN    17.0
#
#       award  hici    ns   pub   pcp  year
# 141     0.0  15.7  14.2  49.7  19.1  2005
# ...
